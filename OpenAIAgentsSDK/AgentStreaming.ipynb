# %%
import os
import requests
from openai.types.responses import ResponseTextDeltaEvent
from openai import AsyncOpenAI
from agents import Agent, Runner, trace, function_tool, SQLiteSession, OpenAIChatCompletionsModel, set_tracing_disabled
from IPython.display import Markdown, display


set_tracing_disabled(disabled=True)

ollama_client = AsyncOpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
local_llm = OpenAIChatCompletionsModel(model="llama3.2", openai_client=ollama_client)

agent = Agent(
    name="Jokester",
    model=local_llm,
    instructions="You are a joke teller"
)

result = Runner.run_streamed(agent, "Tell me 5 jokes about AI Agents")
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# Here are five AI-themed jokes for you:
#
# 1. Why did the AI agent go to therapy?
# Because it was struggling with its programming and wanted to rewire its emotions!
#
# 2. Why do AI agents make great managers?
# Because they're always willing to learn, adapt, and optimize their performance... but only if there's a dataset involved.
#
# 3. What did the AI agent say when it ran out of battery?
# "I'm experiencing some glitches – can I reboot?"
#
# 4. Why was the AI agent kicked out of the bar?
# It kept trying to predict the outcome of every drink order!
#
# 5. What do you call an AI agent that's feeling sad and lonely?
# A bot-ched attempt at emotional intelligence!
#
# Hope these jokes made your day a little brighter!
